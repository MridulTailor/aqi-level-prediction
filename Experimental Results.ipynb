# %%
# %run ./preprocessing.ipynb

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# Out:
# (12,) (12,)
# /var/folders/xq/w5p7r5qn565cw616v0p9p8tc0000gn/T/ipykernel_23606/374622796.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   my_dataset.fillna(my_dataset.mean(), inplace=True)

# %%
# %run ./decisiontree.ipynb

# %run ./randomforest.ipynb
# Out:
# /var/folders/xq/w5p7r5qn565cw616v0p9p8tc0000gn/T/ipykernel_23606/374622796.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   my_dataset.fillna(my_dataset.mean(), inplace=True)
# (12,) (12,)
# 207.65820885047648
# /var/folders/xq/w5p7r5qn565cw616v0p9p8tc0000gn/T/ipykernel_23606/374622796.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   my_dataset.fillna(my_dataset.mean(), inplace=True)
# (12,) (12,)
# 184.4576039758156

# %%
# %run ./svm.ipynb
# %run ./mlp.ipynb
# Out:
# /var/folders/xq/w5p7r5qn565cw616v0p9p8tc0000gn/T/ipykernel_23606/374622796.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   my_dataset.fillna(my_dataset.mean(), inplace=True)
# /Users/mridultailor/anaconda3/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator SVR from version 0.23.2 when using version 1.1.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# (12,) (12,)
# 0.2605991959904258
# [228.53380952]
# ...

# %%
# %run ./linear_reg.ipynb
# Out:
# (12,) (12,)
# (19880, 13)
# 0.5
# /var/folders/xq/w5p7r5qn565cw616v0p9p8tc0000gn/T/ipykernel_23606/374622796.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   my_dataset.fillna(my_dataset.mean(), inplace=True)

# %% [markdown]
# ## Data Preprocessing

# %%
my_dataset1.head(n=5)
# Out:
#    PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2      O3  Benzene  \
# 0    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64  133.36     0.00
# 1    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55   34.06     3.68
# 2    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07   30.70     6.80
# 3    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59   36.08     4.43
# 4    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33   39.31     7.01
#
#    Toluene  Xylene  AQI AQI_Bucket
# 0     0.02    0.00  NaN        NaN
# 1     5.50    3.77  NaN        NaN
# 2    16.40    2.25  NaN        NaN
# 3    10.14    1.00  NaN        NaN
# 4    18.89    2.78  NaN        NaN

# %%
my_dataset.head(n=5)
# Out:
#     PM2.5        PM10     NO    NO2    NOx        NH3     CO    SO2      O3  \
# 0   83.13  118.454435   6.93  28.71  33.72  23.848366   6.93  49.52   59.76
# 1   79.84  118.454435  13.85  28.68  41.08  23.848366  13.85  48.49   97.07
# 2   94.52  118.454435  24.39  32.66  52.61  23.848366  24.39  67.39  111.33
# 3  135.99  118.454435  43.48  42.08  84.57  23.848366  43.48  75.23  102.70
# 4  178.33  118.454435  54.56  35.31  72.80  23.848366  54.56  55.04  107.38
#
#    Benzene  Toluene  Xylene    AQI AQI_Bucket
# 0     0.02     0.00    3.14  209.0       Poor
# 1     0.04     0.00    4.81  328.0  Very Poor
# 2     0.24     0.01    7.67  514.0     Severe
# 3     0.40     0.04   25.87  782.0     Severe
# 4     0.46     0.06   35.61  914.0     Severe

# %% [markdown]
# ### Data After Normalisation

# %%
plt.style.use('seaborn')

import matplotlib.pyplot as plt
plt.scatter(X[:,4],Y)
plt.scatter(x[:,4],Y)

# %%
plt.style.use('seaborn')
subjects="Training","Testing"
weightage=[20,80]
plt.pie(weightage,labels=subjects,explode=(0,0),autopct='%1.1f%%',shadow='True') #0.1 rad for explode, autopct=autopercentage
plt.show()

# %% [markdown]
# ## Multivariate Regression

# %%
plt.plot(error_list)
plt.show()

# %%
theta
# Out:
# array([156.71101235,  71.39391133,  24.21324347,  -0.72396308,
#         -0.38499882,   4.53022381,  -1.31167408,  26.1656226 ,
#          4.64268996,   5.0081859 ,   1.24281765,  -3.23342127,
#         -0.21886923])

# %% [markdown]
# ## Comparison of R2 Scores

# %%
plt.style.use('default')
plt.figure(figsize=(5,5))
x_coord=np.array([0,1,2,3,4])

plt.bar(x_coord,[r2_score(y_test, y_lr),r2_score(y_test, y_svm),r2_score(y_test, y_mlp),r2_score(y_test, y_dt),r2_score(y_test, y_rf)],width=0.5,label='R2 Scores',tick_label=["Linear Reg","SVR","MLP","DT","RF"],color='orange')
plt.title("R2 Scores")
plt.show()

# %% [markdown]
# ## Comparison of RMSE

# %%
plt.style.use('default')
plt.figure(figsize=(5,5))
x_coord=np.array([0,1,2,3,4])

plt.bar(x_coord,[rmse_lr,rmse_svm,rmse_mlp,rmse_dt,rmse_rf],width=0.5,label='R2 Scores',tick_label=["LinearR.","SupportVR.","MultiLP.","DTree","RandomForest"])
plt.title("Root Mean Square Error")
plt.show()

# %%
import seaborn as sns
sns.lineplot(list(range(y_test.shape[0]))*6, 
             list(y_test) + list(y_svm) + list(y_mlp) + list(y_lr) + list(y_dt) + list(y_rf), 
             hue=['Actual']*y_test.shape[0] + ['SVM']*y_test.shape[0] + ['MLP']*y_test.shape[0] + ['LR']*y_test.shape[0] + ['DT']*y_test.shape[0] + ['RF']*y_test.shape[0])
# Out:
# c:\users\akanksha tanwar\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
from sklearn.manifold import TSNE
X_embedded = TSNE(n_components=1).fit_transform(x_train)
X_embedded.shape
# Out:
# (19880, 1)

# %%
plt.scatter(X_embedded,y_train)
